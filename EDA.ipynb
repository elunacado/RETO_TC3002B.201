# %% [markdown]
# # EDA

# %% [markdown]
# ### 1. Imports

# %%
import pandas as pd
pd.reset_option('display.max_colwidth')

# %% [markdown]
# ### 2. Información general

# %%
df = pd.read_csv("data/H-AIRosettaMP.csv")

# %%
df.tail(5)
# Out:
#                                                  task_url  \
# 121242  http://rosettacode.org/wiki/4-rings_or_4-squar...
# 121243            http://rosettacode.org/wiki/ABC_problem
# 121244                http://rosettacode.org/wiki/24_game
# 121245          http://rosettacode.org/wiki/100_prisoners
# 121246                  http://rosettacode.org/wiki/A%2BB
#
#                           task_name  \
# 121242  4-rings or 4-squares puzzle
# 121243                  ABC problem
# 121244                      24 game
# 121245                100 prisoners
# 121246                          A+B
#
#                                          task_description language_name  \
# 121242  4-rings or 4-squares puzzle\n\nYou are encoura...        Kotlin
# 121243  ABC problem\n\nYou are encouraged to solve thi...        Kotlin
# 121244  The 24 Game tests one's mental arithmetic.\n\n...        Kotlin
# 121245  \n\nThe Problem\n\n 100 prisoners are individu...        Kotlin
# 121246  A+B   ─── a classic problem in programming con...        Kotlin
#
#                                                      code         target  \
# 121242  // version 1.1.2\n \nclass FourSquares(\n    p...  Human_written
# 121243  object ABC_block_checker {\n    fun run() {\n ...  Human_written
# 121244  import java.util.Random\nimport java.util.Scan...  Human_written
# 121245  val playOptimal: () -> Boolean = {\n    val se...  Human_written
# 121246  // version 1.0.5-2\n \nfun main(args: Array<St...  Human_written
#
#                      set
# 121242  Kotlin_from_Rust
# 121243  Kotlin_from_Rust
# 121244  Kotlin_from_Rust
# 121245  Kotlin_from_Rust
# 121246  Kotlin_from_Rust

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 121247 entries, 0 to 121246
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   task_url          121247 non-null  str
#  1   task_name         121247 non-null  str
#  2   task_description  121195 non-null  str
#  3   language_name     121247 non-null  str
#  4   code              121205 non-null  str
#  5   target            121247 non-null  str
#  6   set               121247 non-null  str
# dtypes: str(7)
# memory usage: 6.5 MB

# %% [markdown]
# ### 3. Balance de información

# %%
df["target"].value_counts()
# Out:
# target
# Human_written    60624
# Ai_generated     60623
# Name: count, dtype: int64

# %%
df["language_name"].unique()
# Out:
# <StringArray>
# [      'Java',        'cpp',     'Python', 'JavaScript',         'C#',
#           'C',         'Go',       'Ruby',       'Rust',     'Kotlin']
# Length: 10, dtype: str

# %%
df["language_name"].value_counts()
# Out:
# language_name
# Go            13763
# Python        13737
# Ruby          13335
# Java          12351
# Kotlin        12256
# cpp           12029
# C             11715
# C#            11331
# Rust          10665
# JavaScript    10065
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Duplicados

# %%
df.dropna(inplace=True)

# %%
df["code"].duplicated().sum()
# Out:
# np.int64(52483)

# %%
grouped_df = df.groupby('code').agg(list).reset_index()

# %%
grouped_df.head(1)
# Out:
#                                                 code  \
# 0  """\n  Compute nearest pair of points using tw...
#
#                                             task_url  \
# 0  [http://rosettacode.org/wiki/Closest-pair_prob...
#
#                                            task_name  \
# 0  [Closest-pair problem, Closest-pair problem, C...
#
#                                     task_description  \
# 0  [\n\n This page uses content from Wikipedia. T...
#
#                               language_name  \
# 0  [Python, Python, Python, Python, Python]
#
#                                               target  \
# 0  [Human_written, Human_written, Human_written, ...
#
#                                                  set
# 0  [Python_from_JavaScript, Python_from_C#, Pytho...

# %%
df["task_name"].duplicated().sum()
# Out:
# np.int64(120027)

# %%
grouped = df.groupby('task_name').size()
grouped.head(20)
# Out:
# task_name
# 100 doors                             176
# 100 prisoners                         156
# 15 puzzle game                         40
# 15 puzzle solver                        2
# 21 game                                52
# 24 game                               126
# 24 game/Solve                          56
# 4-rings or 4-squares puzzle           146
# 9 billion names of God the integer    172
# 99 bottles of beer                     80
# A+B                                   170
# ABC problem                           158
# AKS test for primes                   166
# ASCII art diagram converter            12
# AVL tree                               10
# Abbreviations, automatic              166
# Abbreviations, easy                   106
# Abbreviations, simple                  74
# Abelian sandpile model                 24
# Abelian sandpile model/Identity        12
# dtype: int64

# %% [markdown]
# ### 5. Balance y duplicados en Python

# %%
df_python = df[df['language_name'] == 'Python']
df_python.head()
# Out:
#                                                 task_url  \
# 24380    http://rosettacode.org/wiki/Array_concatenation
# 24381     http://rosettacode.org/wiki/Arithmetic/Integer
# 24382  http://rosettacode.org/wiki/Arithmetic-geometr...
# 24383  http://rosettacode.org/wiki/Arithmetic-geometr...
# 24384    http://rosettacode.org/wiki/Arithmetic/Rational
#
#                                     task_name  \
# 24380                     Array concatenation
# 24381                      Arithmetic/Integer
# 24382  Arithmetic-geometric mean/Calculate Pi
# 24383               Arithmetic-geometric mean
# 24384                     Arithmetic/Rational
#
#                                         task_description language_name  \
# 24380  Task\n\nShow how to concatenate two arrays in ...        Python
# 24381  \nBasic Data Operation\n\nThis is a basic data...        Python
# 24382  Almkvist Berndt 1988 begins with an investigat...        Python
# 24383  \n\n This page uses content from Wikipedia. Th...        Python
# 24384  Task\n\nCreate a reasonably complete implement...        Python
#
#                                                     code        target  \
# 24380  def concat(arr1, arr2):\n    res = [None] * (l...  Ai_generated
# 24381  import java.util.Scanner;\n \npublic class Flo...  Ai_generated
# 24382  import math\nfrom decimal import *\n\ngetconte...  Ai_generated
# 24383  # Arithmetic-Geometric Mean of 1 & 1/sqrt(2)\n...  Ai_generated
# 24384  from fractions import Fraction\n\nMAX_NUM = 1 ...  Ai_generated
#
#                     set
# 24380  Python_from_Java
# 24381  Python_from_Java
# 24382  Python_from_Java
# 24383  Python_from_Java
# 24384  Python_from_Java

# %%
df_python.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 13718 entries, 24380 to 38116
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   task_url          13718 non-null  str
#  1   task_name         13718 non-null  str
#  2   task_description  13718 non-null  str
#  3   language_name     13718 non-null  str
#  4   code              13718 non-null  str
#  5   target            13718 non-null  str
#  6   set               13718 non-null  str
# dtypes: str(7)
# memory usage: 857.4 KB

# %%
df["target"].value_counts()
# Out:
# target
# Human_written    60590
# Ai_generated     60563
# Name: count, dtype: int64

# %%
df_python["code"].duplicated().sum()
# Out:
# np.int64(5843)
